# %% [markdown]
# < [Notebook 10](PartIII3.ipynb) | [PyFinLab Index](ALWAYS-START-HERE.ipynb) | [Notebook 12](PartIV1.ipynb) >
#
# <a id = "ref00"></a>

# %% [markdown]
# <a><img src="figures/UUBS.png" width="180" height="180" border="10" /></a>
#
# <hr>

# %% [markdown]
# ### Notebook 11: Hypothesis testing
#
# In this notebook we illustrate the need to demonstrate the validity of any assertions we may wish to make as part of any statistical analysis. For example, suppose you are a venture capitalist and have received the proposition of a project which has been running for two years. Based on the data you have at hand, the decision to make is whether or not you should invest in this project. Suppose you will decide to invest if average monthly profit is at least £7,000. This situation does not require you to explicitly estimate some parameter values. Instead, you need to make a judgement on whether or not the condition is satisfied. For such situations we need the statistic tool that is hypothesis testing.

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import microsoft.csv, and add a new feature - logReturn

ms = pd.read_csv('data/microsoft.csv')
ms['logReturn'] = np.log(ms['Close'].shift(-1)) - np.log(ms['Close'])

# %%
# log return goes up and down during the period

ms['logReturn'].plot(figsize=(16, 6))
plt.axhline(0, color='red')
plt.show()

# %% [markdown]
# ### Steps involved in testing a claim by hypothesis testing

# %% [markdown]
# #### Step 1: Set hypothesis

# %% [markdown]
# $H_0 : \mu = 0$
# $H_a : \mu \neq 0$
#
# $H_0$ means the average stock return is equal to 0 <br>
# $H_a$ means the average stock return is not equal to 0

# %% [markdown]
# #### Step 2: Evaluate the test statistic

# %%
sample_mean = ms['logReturn'].mean()
sample_std = ms['logReturn'].std(ddof=1)
n = ms['logReturn'].shape[0]

# when the sample size is large enough (as is the case here), 
# we can use the z-distribution instead of the t-distribtuion 
# [also mu = 0 under the null hypothesis]

zhat = (sample_mean - 0)/(sample_std/(n**0.5))
print(zhat)
# Out:
# 1.6141477140003675

# %% [markdown]
# #### Step 3: Set the desicion criteria

# %%
# confidence level
alpha = 0.05

zleft = norm.ppf(alpha/2, 0, 1)
zright = -zleft  # z-distribution is symmetric 
print(zleft, zright)
# Out:
# -1.9599639845400545 1.9599639845400545

# %% [markdown]
# #### Step 4:  Decision time - shall we reject $H_0$?

# %%
print('At significant level of {}, shall we reject: {}'
      .format(alpha, zhat>zright or zhat<zleft))
# Out:
# At significant level of 0.05, shall we reject: False

# %% [markdown]
# ### Try a one-tail test for yourself !

# %%
# step 1

# %% [markdown]
# $H_0 : \mu \leq 0$
# $H_a : \mu > 0$

# %%
# step 2
sample_mean = ms['logReturn'].mean()
sample_std = ms['logReturn'].std(ddof=1)
n = ms['logReturn'].shape[0]

# when the sample size is large enough (as is the case here), 
# we can use the z-distribution instead of the t-distribtuion 
# [also mu = 0 under the null hypothesis]

zhat = None
print(zhat)

# %% [markdown]
# <div align="right">
# <a href="#galaHag101" class="btn btn-default" data-toggle="collapse">Expected output</a>
#
# </div>
# <div id="galaHag101" class="collapse">
#
# <br>
#
# ```
# 1.6141477140003675
#
# ```
#
# </div>

# %%
# step 3
alpha = 0.05
zright = None 
print(zright)

# %% [markdown]
# <div align="right">
# <a href="#kkk101" class="btn btn-default" data-toggle="collapse">Expected output</a>
#
# </div>
# <div id="kkk101" class="collapse">
#
# <br>
#
# ```
# 1.64485362695
#
# ```
#
# </div>

# %%
# step 4
print('At significant level of {}, shall we reject: {}'
      .format(alpha, None))
# Out:
# At significant level of 0.05, shall we reject: None

# %% [markdown]
# <div align="right">
# <a href="#abcp2603" class="btn btn-default" data-toggle="collapse">Expected output</a>
#
# </div>
# <div id="abcp2603" class="collapse">
#
# <br>
#
# ```
# At significant level of 0.05, shall we reject: False
#
# ```
#
# </div>

# %% [markdown]
# ### An alternative method: p-value

# %%
# steps 1 & 2 as above (no need to recreate)

# %%
# step 3 (p-value)

p = None
print(p)

# %%
# step 4 (decision-time)

# replace None with either alpha or alpha/2 
# as you feel apprpriate or a one-tail test 
print('At significant level of {}, shall we reject: {}'
      .format(alpha, p < None))

# %% [markdown]
# < [Notebook 10](PartIII3.ipynb) | [PyFinLab Index](ALWAYS-START-HERE.ipynb) | [Notebook 12](PartIV1.ipynb) >
#
# <a id = "ref00"></a>
#
# <div align="right"><a href="#ref00">back to top</a></div>
